# %%
import pandas as pd
from ydata_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Loading the new dataset

# %%
df = pd.read_excel("../data/processed/loaded_data.xlsx")

# %% [markdown]
# ## We will pre-process the data and see what are all the missing and duplicate values present in the dataset

# %% [markdown]
# ### Handling Missing values

# %%
df.isnull().sum()
# Out:
# id                       17
# acceptance_rate        7923
# institution              25
# program                1242
# degree_type            1177
# decision               1180
# undergrad_gpa         62618
# gre_general           96604
# gre_verbal            97836
# analytical_writing    98529
# notes                 45900
# gre_total             97998
# dtype: int64

# %% [markdown]
# ### Columns that should NOT be missing (ideally):
# id
# → Must be present and unique for every record.
#
# institution
# → The university/school applied to — essential info.
# 🔸 Should not be missing.
#
# program
# → Program applied to (e.g., MS CS) — needed for analysis.
# 🔸 Should not be missing.
#
# degree_type
# → Such as MS, PhD, etc. — core info.
# 🔸 Should not be missing.
#
# decision
# → Admission result (Accepted/Rejected) — central to analysis.
# 🔸 Should not be missing.

# %%
df = df.dropna(subset=['acceptance_rate', 'institution', 'program', 'degree_type', 'decision'])

# %%
df.isnull().sum()
# Out:
# id                        0
# acceptance_rate           0
# institution               0
# program                   0
# degree_type               0
# decision                  0
# undergrad_gpa         56143
# gre_general           88676
# gre_verbal            89848
# analytical_writing    90504
# notes                 42228
# gre_total             90003
# dtype: int64

# %%
df.shape
# Out:
# (100963, 12)

# %%
# Step 1: Find duplicate IDs
duplicate_ids = df[df.duplicated('id', keep=False)]

# %%
# Convert ID to string to ensure consistent type
duplicate_ids.loc[:,'id'] = duplicate_ids['id'].astype(str)

# Step 2: Sort by 'id' to group duplicates together
duplicate_ids_sorted = duplicate_ids.sort_values(by='id')

# %%
# Step 3: Inspect all rows with the same id
# You can group them and print each group for manual comparison
for dup_id, group in duplicate_ids_sorted.groupby('id'):
    if len(group) > 1:
        print(f"\nDuplicate ID: {dup_id}")
        print(group)
# Out:
# Duplicate ID: 817731
#            id acceptance_rate                      institution  \
# 83003  817731             44%  Georgia Institute Of Technology
# 82983  817731             44%  Georgia Institute Of Technology
#
#                 program degree_type  decision undergrad_gpa gre_general  \
# 83003  Computer Science     Masters  Rejected           3.6         165
# 82983  Computer Science     Masters  Rejected           3.6         165
#
#       gre_verbal analytical_writing notes gre_total
# 83003        159                  4   NaN       324
# 82983        159                  4   NaN       324
#
# Duplicate ID: 817732
#            id acceptance_rate        institution           program  \
# 82982  817732             45%  Purdue University  Computer Science
# 83002  817732             45%  Purdue University  Computer Science
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 82982     Masters  Accepted           NaN         NaN        NaN
# 83002     Masters  Accepted           NaN         NaN        NaN
#
#       analytical_writing notes gre_total
# 82982                NaN   NaN       NaN
# 83002                NaN   NaN       NaN
#
# Duplicate ID: 817733
#            id acceptance_rate                  institution    program  \
# 82981  817733             38%  Central European University  Sociology
# 83001  817733             38%  Central European University  Sociology
#
#       degree_type     decision undergrad_gpa gre_general gre_verbal  \
# 82981     Masters  Wait listed           NaN         NaN        NaN
# 83001     Masters  Wait listed           NaN         NaN        NaN
#
#       analytical_writing notes gre_total
# 82981                NaN   NaN       NaN
# 83001                NaN   NaN       NaN
#
# Duplicate ID: 817734
#            id acceptance_rate            institution    program degree_type  \
# 82980  817734             46%  University of Georgia  Economics         PhD
# 83000  817734             46%  University of Georgia  Economics         PhD
#
#           decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 82980  Wait listed           NaN         NaN        NaN                NaN
# 83000  Wait listed           NaN         NaN        NaN                NaN
#
#       notes gre_total
# 82980   NaN       NaN
# 83000   NaN       NaN
#
# Duplicate ID: 817737
#            id acceptance_rate      institution  \
# 82978  817737             33%  Rice University
# 82998  817737             33%  Rice University
#
#                                      program degree_type  decision  \
# 82978  Materials Science and NanoEngineering         PhD  Rejected
# 82998  Materials Science and NanoEngineering         PhD  Rejected
#
#       undergrad_gpa gre_general gre_verbal analytical_writing notes gre_total
# 82978           NaN         NaN        NaN                NaN   NaN       NaN
# 82998           NaN         NaN        NaN                NaN   NaN       NaN
#
# Duplicate ID: 817738
#            id acceptance_rate            institution     program degree_type  \
# 82977  817738             45%  Georgetown University  Physiology     Masters
# 82997  817738             45%  Georgetown University  Physiology     Masters
#
#           decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 82977  Wait listed           3.5         155        160                  5
# 82997  Wait listed           3.5         155        160                  5
#
#       notes gre_total
# 82977   NaN       315
# 82997   NaN       315
#
# Duplicate ID: 817743
#            id acceptance_rate             institution   program degree_type  \
# 82992  817743             34%  University of Michigan  Robotics     Masters
# 82972  817743             34%  University of Michigan  Robotics     Masters
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 82992  Accepted           NaN         NaN        NaN                NaN   NaN
# 82972  Accepted           NaN         NaN        NaN                NaN   NaN
#
#       gre_total
# 82992       NaN
# 82972       NaN
#
# Duplicate ID: 817744
#            id acceptance_rate              institution           program  \
# 82971  817744             30%  Northwestern University  Computer Science
# 82991  817744             30%  Northwestern University  Computer Science
#
#       degree_type     decision undergrad_gpa gre_general gre_verbal  \
# 82971         PhD  Wait listed           NaN         NaN        NaN
# 82991         PhD  Wait listed           NaN         NaN        NaN
#
#       analytical_writing notes gre_total
# 82971                NaN   NaN       NaN
# 82991                NaN   NaN       NaN
#
# Duplicate ID: 817746
#            id acceptance_rate                    institution  \
# 82989  817746             38%  University of Texas at Austin
# 82969  817746             38%  University of Texas at Austin
#
#                                    program degree_type   decision  \
# 82989  Electrical And Computer Engineering     Masters  Interview
# 82969  Electrical And Computer Engineering     Masters  Interview
#
#       undergrad_gpa gre_general gre_verbal analytical_writing notes gre_total
# 82989           NaN         NaN        NaN                NaN   NaN       NaN
# 82969           NaN         NaN        NaN                NaN   NaN       NaN
#
# Duplicate ID: 817747
#            id acceptance_rate                    institution  \
# 82968  817747             38%  University of Texas at Austin
# 82988  817747             38%  University of Texas at Austin
#
#                    program degree_type  decision undergrad_gpa gre_general  \
# 82968  Geological Sciences         PhD  Rejected          2.96         NaN
# 82988  Geological Sciences         PhD  Rejected          2.96         NaN
#
#       gre_verbal analytical_writing notes gre_total
# 82968        NaN                NaN   NaN       NaN
# 82988        NaN                NaN   NaN       NaN
#
# Duplicate ID: 817748
#            id acceptance_rate        institution  \
# 82987  817748             62%  Aarhus University
# 82967  817748             62%  Aarhus University
#
#                                 program degree_type  decision undergrad_gpa  \
# 82987  Economics And Business Economics         PhD  Rejected           NaN
# 82967  Economics And Business Economics         PhD  Rejected           NaN
#
#       gre_general gre_verbal analytical_writing  \
# 82987         NaN        NaN                NaN
# 82967         NaN        NaN                NaN
#
#                                                    notes gre_total
# 82987  "The current state of the project proposal is ...       NaN
# 82967  "The current state of the project proposal is ...       NaN
#
# Duplicate ID: 817749
#            id acceptance_rate             institution program degree_type  \
# 82966  817749             41%  University Of Waterloo   MDSAI     Masters
# 82986  817749             41%  University Of Waterloo   MDSAI     Masters
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 82966  Rejected           NaN         NaN        NaN                NaN
# 82986  Rejected           NaN         NaN        NaN                NaN
#
#                                                    notes gre_total
# 82966  3.47/4 undergrad gpa, 2 semesters yet to go. I...       NaN
# 82986  3.47/4 undergrad gpa, 2 semesters yet to go. I...       NaN
#
# Duplicate ID: 817750
#            id acceptance_rate                  institution            program  \
# 82965  817750             38%  Central European University  Political Science
# 82985  817750             38%  Central European University  Political Science
#
#       degree_type     decision undergrad_gpa gre_general gre_verbal  \
# 82965         PhD  Wait listed           NaN         NaN        NaN
# 82985         PhD  Wait listed           NaN         NaN        NaN
#
#       analytical_writing notes gre_total
# 82965                NaN   NaN       NaN
# 82985                NaN   NaN       NaN
#
# Duplicate ID: 817751
#            id acceptance_rate                        institution  \
# 82984  817751             61%  Rochester Institute of Technology
# 82964  817751             61%  Rochester Institute of Technology
#
#                      program degree_type     decision undergrad_gpa  \
# 82984  Mathematical Modeling         PhD  Wait listed           NaN
# 82964  Mathematical Modeling         PhD  Wait listed           NaN
#
#       gre_general gre_verbal analytical_writing notes gre_total
# 82984         NaN        NaN                NaN   NaN       NaN
# 82964         NaN        NaN                NaN   NaN       NaN
#
# Duplicate ID: 871567
#           id acceptance_rate       institution      program degree_type  \
# 6976  871567             24%  Emory University  Art History         PhD
# 9792  871567             24%  Emory University  Art History         PhD
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 6976  Interview          3.93         NaN        NaN                NaN   NaN
# 9792  Interview          3.93         NaN        NaN                NaN   NaN
#
#      gre_total
# 6976       NaN
# 9792       NaN
#
# Duplicate ID: 871568
#           id acceptance_rate             institution              program  \
# 6975  871568             34%  University of Hartford  Clinical Psychology
# 9791  871568             34%  University of Hartford  Clinical Psychology
#
#      degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 6975        PsyD  Interview           3.5         NaN        NaN
# 9791        PsyD  Interview           3.5         NaN        NaN
#
#      analytical_writing                                 notes gre_total
# 6975                NaN  emailed for virtual 5 hour interview       NaN
# 9791                NaN  emailed for virtual 5 hour interview       NaN
#
# Duplicate ID: 871569
#           id acceptance_rate               institution        program  \
# 9790  871569             34%  Johns Hopkins University  Public Health
# 6974  871569             34%  Johns Hopkins University  Public Health
#
#      degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 9790     Masters  Accepted          3.34         NaN        NaN
# 6974     Masters  Accepted          3.34         NaN        NaN
#
#      analytical_writing notes gre_total
# 9790                NaN   NaN       NaN
# 6974                NaN   NaN       NaN
#
# Duplicate ID: 871570
#           id acceptance_rate  \
# 6973  871570             31%
# 9789  871570             31%
#
#                                            institution       program  \
# 6973  Washington University In St. Louis (WashU/WUSTL)  Microbiology
# 9789  Washington University In St. Louis (WashU/WUSTL)  Microbiology
#
#      degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 6973         PhD  Accepted          3.71         NaN        NaN
# 9789         PhD  Accepted          3.71         NaN        NaN
#
#      analytical_writing               notes gre_total
# 6973                NaN  Master's GPA : 4.0       NaN
# 9789                NaN  Master's GPA : 4.0       NaN
#
# Duplicate ID: 871571
#           id acceptance_rate         institution       program degree_type  \
# 9788  871571             27%  Harvard University  Epidemiology     Masters
# 6972  871571             27%  Harvard University  Epidemiology     Masters
#
#       decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 9788  Accepted          3.34         NaN        NaN                NaN   NaN
# 6972  Accepted          3.34         NaN        NaN                NaN   NaN
#
#      gre_total
# 9788       NaN
# 6972       NaN
#
# Duplicate ID: 871572
#           id acceptance_rate            institution  \
# 9787  871572             45%  Georgetown University
# 6971  871572             45%  Georgetown University
#
#                         program degree_type  decision undergrad_gpa  \
# 9787  Global Infectious Disease         PhD  Rejected           NaN
# 6971  Global Infectious Disease         PhD  Rejected           NaN
#
#      gre_general gre_verbal analytical_writing  \
# 9787         NaN        NaN                NaN
# 6971         NaN        NaN                NaN
#
#                                                   notes gre_total
# 9787  I was told they emailed all their interview in...       NaN
# 6971  I was told they emailed all their interview in...       NaN
#
# Duplicate ID: 871573
#           id acceptance_rate                    institution  \
# 9786  871573             40%  Pennsylvania State University
# 6970  871573             40%  Pennsylvania State University
#
#                      program degree_type   decision undergrad_gpa gre_general  \
# 9786  Comparative Literature     Masters  Interview           3.9         NaN
# 6970  Comparative Literature     Masters  Interview           3.9         NaN
#
#      gre_verbal analytical_writing  \
# 9786        NaN                NaN
# 6970        NaN                NaN
#
#                                                   notes gre_total
# 9786  got an email to interview with poi mentioned i...       NaN
# 6970  got an email to interview with poi mentioned i...       NaN
#
# Duplicate ID: 871574
#           id acceptance_rate             institution            program  \
# 6969  871574             34%  University of Michigan  Social Psychology
# 9785  871574             34%  University of Michigan  Social Psychology
#
#      degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 6969         PhD  Rejected             4         NaN        NaN
# 9785         PhD  Rejected             4         NaN        NaN
#
#      analytical_writing                                      notes gre_total
# 6969                NaN  received generic email. undergrad alumni.       NaN
# 9785                NaN  received generic email. undergrad alumni.       NaN
#
# Duplicate ID: 871575
#           id acceptance_rate             institution  \
# 6968  871575             34%  University of Michigan
# 9784  871575             34%  University of Michigan
#
#                        program degree_type  decision undergrad_gpa  \
# 6968  Developmental Psychology         PhD  Rejected           NaN
# 9784  Developmental Psychology         PhD  Rejected           NaN
#
#      gre_general gre_verbal analytical_writing notes gre_total
# 6968         NaN        NaN                NaN   NaN       NaN
# 9784         NaN        NaN                NaN   NaN       NaN
#
# Duplicate ID: 871576
#           id acceptance_rate                     institution  \
# 9783  871576             40%  University of Colorado Boulder
# 6967  871576             40%  University of Colorado Boulder
#
#                      program degree_type   decision undergrad_gpa gre_general  \
# 9783  Biomedical Engineering         PhD  Interview           NaN         NaN
# 6967  Biomedical Engineering         PhD  Interview           NaN         NaN
#
#      gre_verbal analytical_writing  \
# 9783        NaN                NaN
# 6967        NaN                NaN
#
#                                                   notes gre_total
# 9783  Invited to an in-person recruitment event for ...       NaN
# 6967  Invited to an in-person recruitment event for ...       NaN
#
# Duplicate ID: 871577
#           id acceptance_rate             institution            program  \
# 9782  871577             34%  University of Michigan  Social Psychology
# 6966  871577             34%  University of Michigan  Social Psychology
#
#      degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 9782         PhD  Rejected          3.86         NaN        NaN
# 6966         PhD  Rejected          3.86         NaN        NaN
#
#      analytical_writing                                              notes  \
# 9782                NaN  straight application from undergrad, interests...
# 6966                NaN  straight application from undergrad, interests...
#
#      gre_total
# 9782       NaN
# 6966       NaN
#
# Duplicate ID: 871578
#           id acceptance_rate        institution    program degree_type  \
# 9781  871578             45%  Purdue University  Chemistry         PhD
# 6965  871578             45%  Purdue University  Chemistry         PhD
#
#       decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 9781  Accepted          3.47         NaN        NaN                NaN
# 6965  Accepted          3.47         NaN        NaN                NaN
#
#                                                   notes gre_total
# 9781  I received a mail from the assistant HOD of th...       NaN
# 6965  I received a mail from the assistant HOD of th...       NaN
#
# Duplicate ID: 871579
#           id acceptance_rate                       institution  \
# 9780  871579             43%  Florida International University
# 6964  871579             43%  Florida International University
#
#                program degree_type     decision undergrad_gpa gre_general  \
# 9780  Legal Psychology         PhD  Wait listed          3.06         NaN
# 6964  Legal Psychology         PhD  Wait listed          3.06         NaN
#
#      gre_verbal analytical_writing  \
# 9780        NaN                NaN
# 6964        NaN                NaN
#
#                                                   notes gre_total
# 9780  MA PsychnScience GPA: 3.96. Emailed the progra...       NaN
# 6964  MA PsychnScience GPA: 3.96. Emailed the progra...       NaN
#
# Duplicate ID: 871580
#           id acceptance_rate            institution              program  \
# 9779  871580             43%  University of Vermont  Clinical Psychology
# 6963  871580             43%  University of Vermont  Clinical Psychology
#
#      degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 9779         PhD  Interview           NaN         NaN        NaN
# 6963         PhD  Interview           NaN         NaN        NaN
#
#      analytical_writing                             notes gre_total
# 9779                NaN  Has anyone heard from MP at UVM?       NaN
# 6963                NaN  Has anyone heard from MP at UVM?       NaN
#
# Duplicate ID: 871581
#           id acceptance_rate             institution            program  \
# 6962  871581             34%  University of Michigan  Social Psychology
# 9778  871581             34%  University of Michigan  Social Psychology
#
#      degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 6962         PhD  Rejected           3.6         NaN        NaN
# 9778         PhD  Rejected           3.6         NaN        NaN
#
#      analytical_writing notes gre_total
# 6962                NaN   NaN       NaN
# 9778                NaN   NaN       NaN
#
# Duplicate ID: 871582
#           id acceptance_rate          institution    program degree_type  \
# 6961  871582             40%  Columbia University  Chemistry         PhD
# 9777  871582             40%  Columbia University  Chemistry         PhD
#
#       decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 6961  Rejected           NaN         NaN        NaN                NaN   NaN
# 9777  Rejected           NaN         NaN        NaN                NaN   NaN
#
#      gre_total
# 6961       NaN
# 9777       NaN
#
# Duplicate ID: 871583
#           id acceptance_rate                    institution  \
# 6960  871583             38%  University of Texas at Austin
# 9776  871583             38%  University of Texas at Austin
#
#                            program degree_type  decision undergrad_gpa  \
# 6960  Government Political Science         PhD  Accepted          3.89
# 9776  Government Political Science         PhD  Accepted          3.89
#
#      gre_general gre_verbal analytical_writing notes gre_total
# 6960         167        167                4.5   NaN       334
# 9776         167        167                4.5   NaN       334
#
# Duplicate ID: 871584
#           id acceptance_rate             institution            program  \
# 6959  871584             34%  University of Michigan  Social Psychology
# 9775  871584             34%  University of Michigan  Social Psychology
#
#      degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 6959         PhD  Rejected             4         NaN        NaN
# 9775         PhD  Rejected             4         NaN        NaN
#
#      analytical_writing                                              notes  \
# 6959                NaN  No GRE, MPP from Georgetown (GPA 3.8). 1 year ...
# 9775                NaN  No GRE, MPP from Georgetown (GPA 3.8). 1 year ...
#
#      gre_total
# 6959       NaN
# 9775       NaN
#
# Duplicate ID: 871585
#           id acceptance_rate         institution      program degree_type  \
# 6958  871585             31%  Cornell University  Linguistics         PhD
# 9774  871585             31%  Cornell University  Linguistics         PhD
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 6958  Interview           NaN         NaN        NaN                NaN   NaN
# 9774  Interview           NaN         NaN        NaN                NaN   NaN
#
#      gre_total
# 6958       NaN
# 9774       NaN
#
# Duplicate ID: 871586
#           id acceptance_rate       institution    program degree_type  \
# 6957  871586             23%  Brown University  Chemistry         PhD
# 9773  871586             23%  Brown University  Chemistry         PhD
#
#          decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 6957  Wait listed           NaN         NaN        NaN                NaN
# 9773  Wait listed           NaN         NaN        NaN                NaN
#
#                                                   notes gre_total
# 6957  Has anyone heard back from Chemistry PhD progr...       NaN
# 9773  Has anyone heard back from Chemistry PhD progr...       NaN
#
# Duplicate ID: 939398
#            id acceptance_rate            institution              program  \
# 31099  939398            0.46  University Of Georgia  Clinical Psychology
# 31128  939398            0.46  University Of Georgia  Clinical Psychology
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31099         PhD  Rejected             4         NaN        NaN
# 31128         PhD  Rejected             4         NaN        NaN
#
#       analytical_writing notes gre_total
# 31099                NaN   NaN       NaN
# 31128                NaN   NaN       NaN
#
# Duplicate ID: 939399
#            id acceptance_rate              institution              program  \
# 31098  939399            0.59  George Mason University  Statistical Science
# 31127  939399            0.59  George Mason University  Statistical Science
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31098         PhD  Accepted           NaN         NaN        NaN
# 31127         PhD  Accepted           NaN         NaN        NaN
#
#       analytical_writing notes gre_total
# 31098                NaN   NaN       NaN
# 31127                NaN   NaN       NaN
#
# Duplicate ID: 939400
#            id acceptance_rate               institution           program  \
# 31097  939400            0.51  Arizona State University  Computer Science
# 31126  939400            0.51  Arizona State University  Computer Science
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31097     Masters  Accepted           3.6         322        157
# 31126     Masters  Accepted           3.6         322        157
#
#       analytical_writing                                          notes  \
# 31097              99.99  Toefl - 110, Took 2 weeks to get the decision
# 31126              99.99  Toefl - 110, Took 2 weeks to get the decision
#
#       gre_total
# 31097       479
# 31126       479
#
# Duplicate ID: 939401
#            id acceptance_rate         institution  program degree_type  \
# 31125  939401            0.38  University Of Iowa  Nursing         PhD
# 31096  939401            0.38  University Of Iowa  Nursing         PhD
#
#         decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 31125  Interview          3.37         NaN        NaN                NaN
# 31096  Interview          3.37         NaN        NaN                NaN
#
#       notes gre_total
# 31125   NaN       NaN
# 31096   NaN       NaN
#
# Duplicate ID: 939402
#            id acceptance_rate               institution              program  \
# 31095  939402            0.38  Indiana State University  Clinical Psychology
# 31124  939402            0.38  Indiana State University  Clinical Psychology
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31095        PsyD  Rejected           NaN         NaN        NaN
# 31124        PsyD  Rejected           NaN         NaN        NaN
#
#       analytical_writing notes gre_total
# 31095                NaN   NaN       NaN
# 31124                NaN   NaN       NaN
#
# Duplicate ID: 939403
#            id acceptance_rate              institution    program degree_type  \
# 31123  939403            0.36  University Of Rochester  Chemistry         PhD
# 31094  939403            0.36  University Of Rochester  Chemistry         PhD
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 31123  Accepted           NaN         NaN        NaN                NaN   NaN
# 31094  Accepted           NaN         NaN        NaN                NaN   NaN
#
#       gre_total
# 31123       NaN
# 31094       NaN
#
# Duplicate ID: 939404
#            id acceptance_rate              institution         program  \
# 31122  939404            0.39  University of Minnesota  German Studies
# 31093  939404            0.39  University of Minnesota  German Studies
#
#       degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 31122         PhD  Interview           NaN         NaN        NaN
# 31093         PhD  Interview           NaN         NaN        NaN
#
#       analytical_writing                             notes gre_total
# 31122                NaN  Invited to interview, 4.0 MA GPA       NaN
# 31093                NaN  Invited to interview, 4.0 MA GPA       NaN
#
# Duplicate ID: 939405
#            id acceptance_rate  \
# 31121  939405            0.31
# 31092  939405            0.31
#
#                                             institution              program  \
# 31121  Washington University In St. Louis (WashU/WUSTL)  Biological Sciences
# 31092  Washington University In St. Louis (WashU/WUSTL)  Biological Sciences
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31121         PhD  Accepted           NaN         NaN        NaN
# 31092         PhD  Accepted           NaN         NaN        NaN
#
#       analytical_writing                                 notes gre_total
# 31121                NaN  Invited the virtual interview. DRSCB       NaN
# 31092                NaN  Invited the virtual interview. DRSCB       NaN
#
# Duplicate ID: 939406
#            id acceptance_rate            institution            program  \
# 31120  939406            0.43  Ohio State University  Social Psychology
# 31091  939406            0.43  Ohio State University  Social Psychology
#
#       degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 31120         PhD  Interview          3.95         NaN        NaN
# 31091         PhD  Interview          3.95         NaN        NaN
#
#       analytical_writing               notes gre_total
# 31120                NaN  Email from faculty       NaN
# 31091                NaN  Email from faculty       NaN
#
# Duplicate ID: 939407
#            id acceptance_rate                    institution  \
# 31090  939407            0.38  University of Texas at Austin
# 31119  939407            0.38  University of Texas at Austin
#
#                  program degree_type   decision undergrad_gpa gre_general  \
# 31090  Social Psychology         PhD  Interview          3.95         NaN
# 31119  Social Psychology         PhD  Interview          3.95         NaN
#
#       gre_verbal analytical_writing  \
# 31090        NaN                NaN
# 31119        NaN                NaN
#
#                                             notes gre_total
# 31090  Invited for virtual interview with faculty       NaN
# 31119  Invited for virtual interview with faculty       NaN
#
# Duplicate ID: 939408
#            id acceptance_rate            institution            program  \
# 31089  939408            0.43  University Of Florida  Social Psychology
# 31118  939408            0.43  University Of Florida  Social Psychology
#
#       degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 31089         PhD  Interview          3.95         NaN        NaN
# 31118         PhD  Interview          3.95         NaN        NaN
#
#       analytical_writing                                  notes gre_total
# 31089                NaN  Invited for email and phone interview       NaN
# 31118                NaN  Invited for email and phone interview       NaN
#
# Duplicate ID: 939409
#            id acceptance_rate            institution            program  \
# 31117  939409             0.4  University Of Houston  Social Psychology
# 31088  939409             0.4  University Of Houston  Social Psychology
#
#       degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 31117         PhD  Interview          3.95         NaN        NaN
# 31088         PhD  Interview          3.95         NaN        NaN
#
#       analytical_writing                          notes gre_total
# 31117                NaN  Invited for virtual interview       NaN
# 31088                NaN  Invited for virtual interview       NaN
#
# Duplicate ID: 939410
#            id acceptance_rate                   institution  \
# 31116  939410             0.3  Sam Houston State University
# 31087  939410             0.3  Sam Houston State University
#
#                    program degree_type   decision undergrad_gpa gre_general  \
# 31116  Clinical Psychology         PhD  Interview          3.95         NaN
# 31087  Clinical Psychology         PhD  Interview          3.95         NaN
#
#       gre_verbal analytical_writing  \
# 31116        NaN                NaN
# 31087        NaN                NaN
#
#                                                    notes gre_total
# 31116  GPA is Master's. Got an email Friday from the ...       NaN
# 31087  GPA is Master's. Got an email Friday from the ...       NaN
#
# Duplicate ID: 939411
#            id acceptance_rate                       institution  \
# 31115  939411             0.4  University of California, Irvine
# 31086  939411             0.4  University of California, Irvine
#
#                        program degree_type   decision undergrad_gpa  \
# 31115  Pharmaceutical Sciences         PhD  Interview          3.37
# 31086  Pharmaceutical Sciences         PhD  Interview          3.37
#
#       gre_general gre_verbal analytical_writing  \
# 31115         NaN        NaN                NaN
# 31086         NaN        NaN                NaN
#
#                                                    notes gre_total
# 31115  I got an email “congratulations! PhD Campus Vi...       NaN
# 31086  I got an email “congratulations! PhD Campus Vi...       NaN
#
# Duplicate ID: 939412
#            id acceptance_rate                      institution  \
# 31085  939412             0.5  University of North Texas (UNT)
# 31114  939412             0.5  University of North Texas (UNT)
#
#                    program degree_type   decision undergrad_gpa gre_general  \
# 31085  Clinical Psychology         PhD  Interview           NaN         NaN
# 31114  Clinical Psychology         PhD  Interview           NaN         NaN
#
#       gre_verbal analytical_writing             notes gre_total
# 31085        NaN                NaN  Prelim interview       NaN
# 31114        NaN                NaN  Prelim interview       NaN
#
# Duplicate ID: 939413
#            id acceptance_rate            institution              program  \
# 31084  939413            0.43  University Of Florida  Clinical Psychology
# 31113  939413            0.43  University Of Florida  Clinical Psychology
#
#       degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 31084         PhD  Interview           NaN         NaN        NaN
# 31113         PhD  Interview           NaN         NaN        NaN
#
#       analytical_writing                                           notes  \
# 31084                NaN  Invite for official interview day (no prelims)
# 31113                NaN  Invite for official interview day (no prelims)
#
#       gre_total
# 31084       NaN
# 31113       NaN
#
# Duplicate ID: 939414
#            id acceptance_rate                           institution  \
# 31112  939414            0.48  University of Illinois Chicago (UIC)
# 31083  939414            0.48  University of Illinois Chicago (UIC)
#
#              program degree_type  decision undergrad_gpa gre_general  \
# 31112  Public Health       Other  Accepted          3.94         NaN
# 31083  Public Health       Other  Accepted          3.94         NaN
#
#       gre_verbal analytical_writing  \
# 31112        NaN                NaN
# 31083        NaN                NaN
#
#                                                    notes gre_total
# 31112  "We are very pleased to recommend you for admi...       NaN
# 31083  "We are very pleased to recommend you for admi...       NaN
#
# Duplicate ID: 939415
#            id acceptance_rate        institution  program degree_type  \
# 31082  939415            0.31  Baylor University  Physics         PhD
# 31111  939415            0.31  Baylor University  Physics         PhD
#
#           decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 31082  Wait listed          3.71         NaN        NaN                NaN
# 31111  Wait listed          3.71         NaN        NaN                NaN
#
#                                                    notes gre_total
# 31082  Hi, has anyone heard from Baylor University sc...       NaN
# 31111  Hi, has anyone heard from Baylor University sc...       NaN
#
# Duplicate ID: 939416
#            id acceptance_rate            institution    program degree_type  \
# 31110  939416            0.32  University Of Chicago  Chemistry         PhD
# 31081  939416            0.32  University Of Chicago  Chemistry         PhD
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 31110  Accepted          3.92         NaN        NaN                NaN
# 31081  Accepted          3.92         NaN        NaN                NaN
#
#                                                    notes gre_total
# 31110  Asked why I wanted to be a graduate student, w...       NaN
# 31081  Asked why I wanted to be a graduate student, w...       NaN
#
# Duplicate ID: 939417
#            id acceptance_rate            institution    program degree_type  \
# 31080  939417            0.32  University Of Chicago  Chemistry         PhD
# 31109  939417            0.32  University Of Chicago  Chemistry         PhD
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 31080  Rejected          3.87         NaN        NaN                NaN   NaN
# 31109  Rejected          3.87         NaN        NaN                NaN   NaN
#
#       gre_total
# 31080       NaN
# 31109       NaN
#
# Duplicate ID: 939418
#            id acceptance_rate             institution              program  \
# 31108  939418            0.34  University of Virginia  Clinical Psychology
# 31079  939418            0.34  University of Virginia  Clinical Psychology
#
#       degree_type   decision undergrad_gpa gre_general gre_verbal  \
# 31108         PhD  Interview           NaN         NaN        NaN
# 31079         PhD  Interview           NaN         NaN        NaN
#
#       analytical_writing             notes gre_total
# 31108                NaN  prelim interview       NaN
# 31079                NaN  prelim interview       NaN
#
# Duplicate ID: 939419
#            id acceptance_rate            institution    program degree_type  \
# 31107  939419            0.43  University Of Florida  Chemistry         PhD
# 31078  939419            0.43  University Of Florida  Chemistry         PhD
#
#         decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 31107  Interview          3.74         NaN        NaN                NaN
# 31078  Interview          3.74         NaN        NaN                NaN
#
#                                                    notes gre_total
# 31107  I received an email on Dec 15 of zoom intervie...       NaN
# 31078  I received an email on Dec 15 of zoom intervie...       NaN
#
# Duplicate ID: 939420
#            id acceptance_rate         institution                program  \
# 31077  939420            0.38  University Of Iowa  Counseling Psychology
# 31106  939420            0.38  University Of Iowa  Counseling Psychology
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31077        PsyD  Rejected           NaN         318        NaN
# 31106        PsyD  Rejected           NaN         318        NaN
#
#       analytical_writing notes gre_total
# 31077                NaN   NaN       NaN
# 31106                NaN   NaN       NaN
#
# Duplicate ID: 939421
#            id acceptance_rate              institution            program  \
# 31105  939421             0.3  Northwestern University  Social Psychology
# 31076  939421             0.3  Northwestern University  Social Psychology
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31105         PhD  Rejected          3.87         NaN        NaN
# 31076         PhD  Rejected          3.87         NaN        NaN
#
#       analytical_writing                                              notes  \
# 31105                NaN  I got an email from the Professor saying he ha...
# 31076                NaN  I got an email from the Professor saying he ha...
#
#       gre_total
# 31105       NaN
# 31076       NaN
#
# Duplicate ID: 939422
#            id acceptance_rate       institution  \
# 31104  939422            0.53  Adler University
# 31075  939422            0.53  Adler University
#
#                                  program degree_type   decision undergrad_gpa  \
# 31104  Clinical Mental Health Counseling     Masters  Interview          3.54
# 31075  Clinical Mental Health Counseling     Masters  Interview          3.54
#
#       gre_general gre_verbal analytical_writing notes gre_total
# 31104         NaN        NaN                NaN   NaN       NaN
# 31075         NaN        NaN                NaN   NaN       NaN
#
# Duplicate ID: 939423
#            id acceptance_rate      institution                program  \
# 31103  939423            0.23  Yale University  Computational Biology
# 31074  939423            0.23  Yale University  Computational Biology
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31103     Masters  Accepted          3.59         NaN        NaN
# 31074     Masters  Accepted          3.59         NaN        NaN
#
#       analytical_writing notes gre_total
# 31103                NaN   NaN       NaN
# 31074                NaN   NaN       NaN
#
# Duplicate ID: 939424
#            id acceptance_rate        institution               program  \
# 31073  939424            0.45  Purdue University  Chemical Engineering
# 31102  939424            0.45  Purdue University  Chemical Engineering
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 31073     Masters  Accepted          3.23         NaN        NaN
# 31102     Masters  Accepted          3.23         NaN        NaN
#
#       analytical_writing notes gre_total
# 31073                NaN   NaN       NaN
# 31102                NaN   NaN       NaN
#
# Duplicate ID: 939425
#            id acceptance_rate               institution  \
# 31072  939425             0.4  Georgia State University
# 31101  939425             0.4  Georgia State University
#
#                      program degree_type   decision undergrad_gpa gre_general  \
# 31072  Counseling Psychology         PhD  Interview             4         NaN
# 31101  Counseling Psychology         PhD  Interview             4         NaN
#
#       gre_verbal analytical_writing notes gre_total
# 31072        NaN                NaN   NaN       NaN
# 31101        NaN                NaN   NaN       NaN
#
# Duplicate ID: 939426
#            id acceptance_rate    institution  \
# 31071  939426             0.5  Virginia Tech
# 31100  939426             0.5  Virginia Tech
#
#                                     program degree_type  decision  \
# 31071  Industrial Organizational Psychology         PhD  Rejected
# 31100  Industrial Organizational Psychology         PhD  Rejected
#
#       undergrad_gpa gre_general gre_verbal analytical_writing  \
# 31071           NaN         NaN        NaN                NaN
# 31100           NaN         NaN        NaN                NaN
#
#                                           notes gre_total
# 31071  Received an interview request for 12/13.       NaN
# 31100  Received an interview request for 12/13.       NaN
#
# Duplicate ID: 964029
#            id acceptance_rate               institution           program  \
# 15400  964029            0.32  University of California  Computer Science
# 57055  964029             32%  University of California  Computer Science
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 15400     Masters  Accepted          3.76         NaN        NaN
# 57055     Masters  Accepted          3.76         NaN        NaN
#
#       analytical_writing notes gre_total
# 15400                NaN   NaN       NaN
# 57055                NaN   NaN       NaN
#
# Duplicate ID: 964030
#            id acceptance_rate                              institution  \
# 15399  964030            0.66  Teachers College at Columbia University
# 57054  964030             66%  Teachers College at Columbia University
#
#                                program degree_type  decision undergrad_gpa  \
# 15399  Urban Education Leaders Program         EdD  Accepted          3.76
# 57054  Urban Education Leaders Program         EdD  Accepted          3.76
#
#       gre_general gre_verbal analytical_writing  \
# 15399         NaN        NaN                NaN
# 57054         NaN        NaN                NaN
#
#                                           notes gre_total
# 15399  Interview 2/10; received acceptance 2/18       NaN
# 57054                                       NaN       NaN
#
# Duplicate ID: 964031
#            id acceptance_rate                      institution  \
# 15398  964031            0.44  Georgia Institute of Technology
# 57053  964031             44%  Georgia Institute of Technology
#
#                                    program degree_type  decision  \
# 15398  Electrical And Computer Engineering         PhD  Accepted
# 57053  Electrical And Computer Engineering         PhD  Accepted
#
#       undergrad_gpa gre_general gre_verbal analytical_writing notes gre_total
# 15398           3.9         NaN        NaN                NaN   NaN       NaN
# 57053           3.9         NaN        NaN                NaN   NaN       NaN
#
# Duplicate ID: 984617
#            id acceptance_rate                 institution       program  \
# 15385  984617            0.44  San Diego State University  Microbiology
# 15410  984617            0.44  San Diego State University  Microbiology
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 15385     Masters  Rejected          3.51         NaN        NaN
# 15410     Masters  Rejected          3.51         NaN        NaN
#
#       analytical_writing notes gre_total
# 15385                NaN   NaN       NaN
# 15410                NaN   NaN       NaN
#
# Duplicate ID: 984618
#            id acceptance_rate                     institution program  \
# 15384  984618            0.38  University of British Columbia   Civil
# 15409  984618            0.38  University of British Columbia   Civil
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 15384       Other  Rejected          3.55         NaN        NaN
# 15409       Other  Rejected          3.55         NaN        NaN
#
#       analytical_writing   notes gre_total
# 15384                NaN  MASCs.       NaN
# 15409                NaN  MASCs.       NaN
#
# Duplicate ID: 984620
#            id acceptance_rate                        institution  \
# 15383  984620            0.22  The University of Texas at Austin
# 15408  984620            0.22  The University of Texas at Austin
#
#                 program degree_type  decision undergrad_gpa gre_general  \
# 15383  Computer Science         PhD  Rejected           NaN         NaN
# 15408  Computer Science         PhD  Rejected           NaN         NaN
#
#       gre_verbal analytical_writing  \
# 15383        NaN                NaN
# 15408        NaN                NaN
#
#                                                    notes gre_total
# 15383  Rejected and recommended to apply to online MS...       NaN
# 15408  Rejected and recommended to apply to online MS...       NaN
#
# Duplicate ID: 984621
#            id acceptance_rate                        institution  \
# 15407  984621            0.51  Maryland Institute College of Art
# 15382  984621            0.51  Maryland Institute College of Art
#
#                      program degree_type     decision undergrad_gpa  \
# 15407  Illustration Practice         MFA  Wait listed          3.72
# 15382  Illustration Practice         MFA  Wait listed          3.72
#
#       gre_general gre_verbal analytical_writing  \
# 15407         NaN        NaN                NaN
# 15382         NaN        NaN                NaN
#
#                                                    notes gre_total
# 15407  Waitlisted as I really want to go here and hop...       NaN
# 15382  Waitlisted as I really want to go here and hop...       NaN
#
# Duplicate ID: 984622
#            id acceptance_rate         institution              program  \
# 15381  984622            0.38  University of Iowa  Applied Mathematics
# 15406  984622            0.38  University of Iowa  Applied Mathematics
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 15381         PhD  Accepted          3.28         NaN        NaN
# 15406         PhD  Accepted          3.28         NaN        NaN
#
#       analytical_writing         notes gre_total
# 15381                NaN  3.30 Masters       NaN
# 15406                NaN  3.30 Masters       NaN
#
# Duplicate ID: 984623
#            id acceptance_rate            institution      program degree_type  \
# 15405  984623            0.44  University of Alabama  PhD Physics         PhD
# 15380  984623            0.44  University of Alabama  PhD Physics         PhD
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing  \
# 15405  Rejected          3.07         NaN        NaN                NaN
# 15380  Rejected          3.07         NaN        NaN                NaN
#
#                                                    notes gre_total
# 15405  1 Year of Research Experience and 1 Year of Te...       NaN
# 15380  1 Year of Research Experience and 1 Year of Te...       NaN
#
# Duplicate ID: 985383
#            id acceptance_rate               institution        program  \
# 14683  985383            0.57  Florida State University  Biostatistics
# 28214  985383            0.57  Florida State University  Biostatistics
# 14524  985383            0.57  Florida State University  Biostatistics
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 14683         PhD  Accepted          3.57         318        NaN
# 28214         PhD  Accepted          3.57         318        NaN
# 14524         PhD  Accepted          3.57         318        NaN
#
#       analytical_writing                                              notes  \
# ...
# 14543         NaN        NaN                NaN   NaN       NaN
# 14426         NaN        NaN                NaN   NaN       NaN
# 28220         NaN        NaN                NaN   NaN       NaN
# 28104         NaN        NaN                NaN   NaN       NaN
# 14414         NaN        NaN                NaN   NaN       NaN
# 14530         NaN        NaN                NaN   NaN       NaN
# 28110         NaN        NaN                NaN   NaN       NaN
# 14475         NaN        NaN                NaN   NaN       NaN
# 14420         NaN        NaN                NaN   NaN       NaN
#
# Duplicate ID: 985543
#            id acceptance_rate              institution  \
# 15397  985543            0.69  University of Edinburgh
# 14474  985543            0.69  University of Edinburgh
# 28164  985543            0.69  University of Edinburgh
# 14529  985543            0.69  University of Edinburgh
# 28103  985543            0.69  University of Edinburgh
# 28219  985543            0.69  University of Edinburgh
# 14425  985543            0.69  University of Edinburgh
# 14419  985543            0.69  University of Edinburgh
# 14413  985543            0.69  University of Edinburgh
# 28109  985543            0.69  University of Edinburgh
# 14542  985543            0.69  University of Edinburgh
# 28115  985543            0.69  University of Edinburgh
#
#                            program degree_type  decision undergrad_gpa  \
# 15397  Natural Language Processing         PhD  Accepted           NaN
# 14474  Natural Language Processing         PhD  Accepted           NaN
# 28164  Natural Language Processing         PhD  Accepted           NaN
# 14529  Natural Language Processing         PhD  Accepted           NaN
# 28103  Natural Language Processing         PhD  Accepted           NaN
# 28219  Natural Language Processing         PhD  Accepted           NaN
# 14425  Natural Language Processing         PhD  Accepted           NaN
# 14419  Natural Language Processing         PhD  Accepted           NaN
# 14413  Natural Language Processing         PhD  Accepted           NaN
# 28109  Natural Language Processing         PhD  Accepted           NaN
# 14542  Natural Language Processing         PhD  Accepted           NaN
# 28115  Natural Language Processing         PhD  Accepted           NaN
#
#       gre_general gre_verbal analytical_writing  \
# 15397         NaN        NaN                NaN
# 14474         NaN        NaN                NaN
# 28164         NaN        NaN                NaN
# 14529         NaN        NaN                NaN
# 28103         NaN        NaN                NaN
# 28219         NaN        NaN                NaN
# 14425         NaN        NaN                NaN
# 14419         NaN        NaN                NaN
# 14413         NaN        NaN                NaN
# 28109         NaN        NaN                NaN
# 14542         NaN        NaN                NaN
# 28115         NaN        NaN                NaN
#
#                                           notes gre_total
# 15397  Got accepted to ILCC 3 years PhD program       NaN
# 14474  Got accepted to ILCC 3 years PhD program       NaN
# 28164  Got accepted to ILCC 3 years PhD program       NaN
# 14529  Got accepted to ILCC 3 years PhD program       NaN
# 28103  Got accepted to ILCC 3 years PhD program       NaN
# 28219  Got accepted to ILCC 3 years PhD program       NaN
# 14425  Got accepted to ILCC 3 years PhD program       NaN
# 14419  Got accepted to ILCC 3 years PhD program       NaN
# 14413  Got accepted to ILCC 3 years PhD program       NaN
# 28109  Got accepted to ILCC 3 years PhD program       NaN
# 14542  Got accepted to ILCC 3 years PhD program       NaN
# 28115  Got accepted to ILCC 3 years PhD program       NaN
#
# Duplicate ID: 985544
#            id acceptance_rate                     institution  \
# 14473  985544            0.78  California College of the Arts
# 14424  985544            0.78  California College of the Arts
# 28218  985544            0.78  California College of the Arts
# 14418  985544            0.78  California College of the Arts
# 28163  985544            0.78  California College of the Arts
# 14412  985544            0.78  California College of the Arts
# 28108  985544            0.78  California College of the Arts
# 28114  985544            0.78  California College of the Arts
# 14528  985544            0.78  California College of the Arts
# 28102  985544            0.78  California College of the Arts
# 14541  985544            0.78  California College of the Arts
# 15396  985544            0.78  California College of the Arts
#
#                   program degree_type  decision undergrad_gpa gre_general  \
# 14473  Interaction Design       Other  Rejected          3.98         NaN
# 14424  Interaction Design       Other  Rejected          3.98         NaN
# 28218  Interaction Design       Other  Rejected          3.98         NaN
# 14418  Interaction Design       Other  Rejected          3.98         NaN
# 28163  Interaction Design       Other  Rejected          3.98         NaN
# 14412  Interaction Design       Other  Rejected          3.98         NaN
# 28108  Interaction Design       Other  Rejected          3.98         NaN
# 28114  Interaction Design       Other  Rejected          3.98         NaN
# 14528  Interaction Design       Other  Rejected          3.98         NaN
# 28102  Interaction Design       Other  Rejected          3.98         NaN
# 14541  Interaction Design       Other  Rejected          3.98         NaN
# 15396  Interaction Design       Other  Rejected          3.98         NaN
#
#       gre_verbal analytical_writing  \
# 14473        NaN                NaN
# 14424        NaN                NaN
# 28218        NaN                NaN
# 14418        NaN                NaN
# 28163        NaN                NaN
# 14412        NaN                NaN
# 28108        NaN                NaN
# 28114        NaN                NaN
# 14528        NaN                NaN
# 28102        NaN                NaN
# 14541        NaN                NaN
# 15396        NaN                NaN
#
#                                                    notes gre_total
# 14473  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 14424  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 28218  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 14418  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 28163  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 14412  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 28108  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 28114  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 14528  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 28102  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 14541  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
# 15396  HAHAHAHA. Okay, I'm going to RISD anyway. But ...       NaN
#
# Duplicate ID: 985545
#            id acceptance_rate          institution          program  \
# 14540  985545             0.4  Columbia University  Applied Physics
# 28113  985545             0.4  Columbia University  Applied Physics
# 28217  985545             0.4  Columbia University  Applied Physics
# 15395  985545             0.4  Columbia University  Applied Physics
# 14417  985545             0.4  Columbia University  Applied Physics
# 14472  985545             0.4  Columbia University  Applied Physics
# 28101  985545             0.4  Columbia University  Applied Physics
# 28162  985545             0.4  Columbia University  Applied Physics
# 14423  985545             0.4  Columbia University  Applied Physics
# 28107  985545             0.4  Columbia University  Applied Physics
# 14527  985545             0.4  Columbia University  Applied Physics
# 14411  985545             0.4  Columbia University  Applied Physics
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 14540         PhD  Rejected           NaN         NaN        NaN
# 28113         PhD  Rejected           NaN         NaN        NaN
# 28217         PhD  Rejected           NaN         NaN        NaN
# 15395         PhD  Rejected           NaN         NaN        NaN
# 14417         PhD  Rejected           NaN         NaN        NaN
# 14472         PhD  Rejected           NaN         NaN        NaN
# 28101         PhD  Rejected           NaN         NaN        NaN
# 28162         PhD  Rejected           NaN         NaN        NaN
# 14423         PhD  Rejected           NaN         NaN        NaN
# 28107         PhD  Rejected           NaN         NaN        NaN
# 14527         PhD  Rejected           NaN         NaN        NaN
# 14411         PhD  Rejected           NaN         NaN        NaN
#
#       analytical_writing notes gre_total
# 14540                NaN   NaN       NaN
# 28113                NaN   NaN       NaN
# 28217                NaN   NaN       NaN
# 15395                NaN   NaN       NaN
# 14417                NaN   NaN       NaN
# 14472                NaN   NaN       NaN
# 28101                NaN   NaN       NaN
# 28162                NaN   NaN       NaN
# 14423                NaN   NaN       NaN
# 28107                NaN   NaN       NaN
# 14527                NaN   NaN       NaN
# 14411                NaN   NaN       NaN
#
# Duplicate ID: 985546
#            id acceptance_rate          institution                 program  \
# 14416  985546             0.4  Columbia University  Electrical Engineering
# 14526  985546             0.4  Columbia University  Electrical Engineering
# 14410  985546             0.4  Columbia University  Electrical Engineering
# 14471  985546             0.4  Columbia University  Electrical Engineering
# 28112  985546             0.4  Columbia University  Electrical Engineering
# 28106  985546             0.4  Columbia University  Electrical Engineering
# 28216  985546             0.4  Columbia University  Electrical Engineering
# 14422  985546             0.4  Columbia University  Electrical Engineering
# 15394  985546             0.4  Columbia University  Electrical Engineering
# 14539  985546             0.4  Columbia University  Electrical Engineering
# 28100  985546             0.4  Columbia University  Electrical Engineering
# 28161  985546             0.4  Columbia University  Electrical Engineering
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 14416     Masters  Rejected           NaN         NaN        NaN
# 14526     Masters  Rejected           NaN         NaN        NaN
# 14410     Masters  Rejected           NaN         NaN        NaN
# 14471     Masters  Rejected           NaN         NaN        NaN
# 28112     Masters  Rejected           NaN         NaN        NaN
# 28106     Masters  Rejected           NaN         NaN        NaN
# 28216     Masters  Rejected           NaN         NaN        NaN
# 14422     Masters  Rejected           NaN         NaN        NaN
# 15394     Masters  Rejected           NaN         NaN        NaN
# 14539     Masters  Rejected           NaN         NaN        NaN
# 28100     Masters  Rejected           NaN         NaN        NaN
# 28161     Masters  Rejected           NaN         NaN        NaN
#
#       analytical_writing                                              notes  \
# 14416                NaN  strung me along until the last possible second...
# 14526                NaN  strung me along until the last possible second...
# 14410                NaN  strung me along until the last possible second...
# 14471                NaN  strung me along until the last possible second...
# 28112                NaN  strung me along until the last possible second...
# 28106                NaN  strung me along until the last possible second...
# 28216                NaN  strung me along until the last possible second...
# 14422                NaN  strung me along until the last possible second...
# 15394                NaN  strung me along until the last possible second...
# 14539                NaN  strung me along until the last possible second...
# 28100                NaN  strung me along until the last possible second...
# 28161                NaN  strung me along until the last possible second...
#
#       gre_total
# 14416       NaN
# 14526       NaN
# 14410       NaN
# 14471       NaN
# 28112       NaN
# 28106       NaN
# 28216       NaN
# 14422       NaN
# 15394       NaN
# 14539       NaN
# 28100       NaN
# 28161       NaN
#
# Duplicate ID: 985547
#            id acceptance_rate            institution        program  \
# 14525  985547             0.5  University at Buffalo  Biotechnology
# 15393  985547             0.5  University at Buffalo  Biotechnology
# 14538  985547             0.5  University at Buffalo  Biotechnology
# 28215  985547             0.5  University at Buffalo  Biotechnology
#
#       degree_type  decision undergrad_gpa gre_general gre_verbal  \
# 14525     Masters  Accepted           3.4         NaN        NaN
# 15393     Masters  Accepted           3.4         NaN        NaN
# 14538     Masters  Accepted           3.4         NaN        NaN
# 28215     Masters  Accepted           3.4         NaN        NaN
#
#       analytical_writing                                              notes  \
# 14525                NaN  Was previously an undergrad at UB in same prog...
# 15393                NaN  Was previously an undergrad at UB in same prog...
# 14538                NaN  Was previously an undergrad at UB in same prog...
# 28215                NaN  Was previously an undergrad at UB in same prog...
#
#       gre_total
# 14525       NaN
# 15393       NaN
# 14538       NaN
# 28215       NaN
#
# Duplicate ID: 985551
#            id acceptance_rate            institution     program degree_type  \
# 15387  985551            0.43  Ohio State University  Statistics         PhD
# 15389  985551            0.43  Ohio State University  Statistics         PhD
#
#        decision undergrad_gpa gre_general gre_verbal analytical_writing notes  \
# 15387  Rejected             4         NaN        NaN                NaN   NaN
# 15389  Rejected             4         NaN        NaN                NaN   NaN
#
#       gre_total
# 15387       NaN
# 15389       NaN
#
# Duplicate ID: 985552
#            id acceptance_rate                       institution  \
# 15386  985552            0.55  Mississippi University for Women
# 15388  985552            0.55  Mississippi University for Women
#
#                          program degree_type  decision undergrad_gpa  \
# 15386  Speech Language Pathology     Masters  Rejected          3.87
# 15388  Speech Language Pathology     Masters  Rejected          3.87
#
#       gre_general gre_verbal analytical_writing  \
# 15386         NaN        NaN                NaN
# 15388         NaN        NaN                NaN
#
#                                                    notes gre_total
# 15386  GRE 300 out of state applicant. gpa 3.87 no NS...       NaN
# 15388  GRE 300 out of state applicant. gpa 3.87 no NS...       NaN
#
# Duplicate ID: ID
#        id  acceptance_rate  institution  program  degree_type  decision  \
# 11880  ID  Acceptance Rate  Institution  Program  Degree Type  Decision
# 8017   ID  Acceptance Rate  Institution  Program  Degree Type  Decision
# 7037   ID  Acceptance Rate  Institution  Program  Degree Type  Decision
#
#        undergrad_gpa  gre_general  gre_verbal  analytical_writing  notes  \
# 11880  Undergrad GPA  GRE General  GRE Verbal  Analytical Writing  Notes
# 8017   Undergrad GPA  GRE General  GRE Verbal  Analytical Writing  Notes
# 7037   Undergrad GPA  GRE General  GRE Verbal  Analytical Writing  Notes
#
#                    gre_total
# 11880  GRE GeneralGRE Verbal
# 8017   GRE GeneralGRE Verbal
# 7037   GRE GeneralGRE Verbal

# %%
# Remove rows that are exact duplicates (all columns identical)
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#             id acceptance_rate               institution           program  \
# count   100629          100629                    100629            100629
# unique  100626             172                      1130              7910
# top     964029             40%  University of California  Computer Science
# freq         2            8486                      4081              7527
#
#        degree_type  decision  undergrad_gpa  gre_general  gre_verbal  \
# count       100629    100629          44646        12256       11095
# unique           9         9            348          143          86
# top            PhD  Accepted              4          170         162
# freq         64772     37248           5320         2106         793
#
#         analytical_writing                  notes  gre_total
# count                10435                  58553      10940
# unique                  98                  54280        185
# top                      4  Email to check portal        330
# freq                  2978                    264        485

# %%
print(df['id'].duplicated().sum())
# Out:
# 3

# %%
duplicate_ids = df[df.duplicated('id', keep=False)]

# %%
df = df.drop_duplicates(subset='id', keep='first')

# %%
print(df['id'].duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#             id acceptance_rate               institution           program  \
# count   100626          100626                    100626            100626
# unique  100626             172                      1130              7910
# top     879550             40%  University of California  Computer Science
# freq         1            8486                      4080              7526
#
#        degree_type  decision  undergrad_gpa  gre_general  gre_verbal  \
# count       100626    100626          44643        12256       11095
# unique           9         9            348          143          86
# top            PhD  Accepted              4          170         162
# freq         64771     37245           5320         2106         793
#
#         analytical_writing                  notes  gre_total
# count                10435                  58553      10940
# unique                  98                  54280        185
# top                      4  Email to check portal        330
# freq                  2978                    264        485

# %%
df.to_excel("../data/processed/preprocessed_data.xlsx", index=False)
